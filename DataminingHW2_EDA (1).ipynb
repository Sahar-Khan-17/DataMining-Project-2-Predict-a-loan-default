# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import auc
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.cluster import KMeans

# %%
#using clean data
data = pd.read_csv("C:/Users/khan1/OneDrive/Desktop/Classes smu/Fall Mod B/datamining/hw2clean/DM hw2 dataset_clean.csv")

 
data.head()

# %%
# Renaming since column name is too long. Default can be used as base
data.rename(columns = {'default payment next month': 'default'}, inplace = True)

# %%
data.default.value_counts()
# Out:
# 0    22996
# 1     6605
# Name: default, dtype: int64

# %%
##To check relationship between Payment History and defaults

## Pattern? : There are highs and lows in every payment record.
#It looks like If a client paid a higher amount last month, they are less likely to default the next month thus we see a high in pay2 and low in pay3 and so on for next paymenets

# %%
sns.relplot(x = 'AGE', y = 'PAY_AMT2',  hue = 'default',kind ='line'  ,data = data)

# %%
 sns.relplot(x = 'AGE', y = 'PAY_AMT3',  hue = 'default',kind ='line'  ,data = data)

# %%
sns.relplot(x = 'AGE', y = 'PAY_AMT4',  hue = 'default',kind ='line'  ,data = data)

# %%
sns.relplot(x = 'AGE', y = 'PAY_AMT5',  hue = 'default',kind ='line'  ,data = data)

# %%
sns.relplot(x = 'AGE', y = 'PAY_AMT6',  hue = 'default',kind ='line'  ,data = data)

# %%
##relationship between credit limit and defaults
#Insight: Clients from age 30 -55 who have a decent credit limit and are less likely to default

sns.relplot(x = 'AGE' ,y = 'LIMIT_BAL', hue = 'default', kind ='line',data = data)

# %%
#relationship between education and default-
#insights: Univerity students default max, followed by graduate student

sns.histplot(x = 'EDUCATION', hue = 'default', data = data)
# Out:
# <AxesSubplot:xlabel='EDUCATION', ylabel='Count'>

# %%
sns.histplot(x = 'MARRIAGE', hue = 'default', data = data) 
##Insights: married and single deafults are almost the same, no significant info
# Out:
# <AxesSubplot:xlabel='MARRIAGE', ylabel='Count'>

# %%
from sklearn.cluster import KMeans
Sum_of_squared_distances = []
K = range(1,10)
for num_clusters in K :
    kmeans = KMeans(n_clusters=num_clusters)
    kmeans.fit(np.array(default.AGE).reshape((-1, 1)))
    Sum_of_squared_distances.append(kmeans.inertia_)
plt.plot(K,Sum_of_squared_distances,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Sum of squared distances/Inertia') 
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 4>()
#       4 for num_clusters in K :
#       5     kmeans = KMeans(n_clusters=num_clusters)
# ----> 6     kmeans.fit(np.array(default.AGE).reshape((-1, 1)))
#       7     Sum_of_squared_distances.append(kmeans.inertia_)
#       8 plt.plot(K,Sum_of_squared_distances,'bx-')
#
# NameError: name 'default' is not defined
